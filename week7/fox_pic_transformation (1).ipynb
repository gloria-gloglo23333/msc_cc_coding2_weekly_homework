# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

import matplotlib.pyplot as plt
import numpy as np


files = []
for file_i in os.listdir('wild'):
    if '.jpg' in file_i:
        files.append(os.path.join('wild', file_i))

# %%
img = plt.imread(files[80])

print(img)
# Out:
# [[[ 51  24  15]
#   [ 51  24  15]
#   [ 50  23  14]
#   ...
#   [ 84  78  80]
#   [ 84  78  80]
#   [ 82  76  78]]
#
#  [[ 49  22  13]
#   [ 49  22  13]
#   [ 50  23  14]
#   ...
#   [ 84  78  80]
#   [ 84  78  80]
#   [ 81  75  77]]
#
#  [[ 47  20  11]
#   [ 48  21  12]
#   [ 49  22  13]
#   ...
#   [ 77  71  73]
#   [ 76  70  72]
#   [ 74  68  70]]
#
#  ...
#
#  [[ 41  19   5]
#   [125 103  89]
#   [ 50  28  15]
#   ...
#   [130 140 150]
#   [138 148 158]
#   [138 150 162]]
#
#  [[ 56  34  20]
#   [130 108  94]
#   [ 61  39  26]
#   ...
#   [134 144 154]
#   [141 151 161]
#   [140 152 164]]
#
#  [[ 48  29  14]
#   [ 33  11   0]
#   [ 39  17   4]
#   ...
#   [139 149 159]
#   [145 155 165]
#   [143 155 167]]]

# %%
plt.imshow(img)

# %%
imgs = [plt.imread(files[file_i])
        for file_i in range(1000)]

# %%
imgs[0].shape
# Out:
# (512, 512, 3)

# %%
data = np.array(imgs) # make 'data' = our numpy array
data.shape
print(data.shape)
print("The shape of our new 'data' object is a 'batch' of 100 images, with a height of 218, width of 178, and 3 colour channels")
print("If your images aren't all the same size to begin with, then this won't work!")
# Out:
# (1000, 512, 512, 3)
# The shape of our new 'data' object is a 'batch' of 100 images, with a height of 218, width of 178, and 3 colour channels
# If your images aren't all the same size to begin with, then this won't work!

# %%
mean_img = np.mean(data, axis=0) # This is the mean of the 'batch' channel
plt.imshow(mean_img.astype(np.uint8))
print("look at this average person")
# Out:
# look at this average person
